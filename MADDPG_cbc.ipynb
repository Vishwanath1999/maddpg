# %%
import os
import datetime
from google.colab import drive
drive.mount('/content/gdrive')

os.chdir('/content/gdrive/My Drive/Reinforcement Learning/actor_critic/MADDPG')
# !ls
# Out:
# Mounted at /content/gdrive

# %%
# !pip install torch==1.4.0
# Out:
# Requirement already satisfied: torch==1.4.0 in /usr/local/lib/python3.7/dist-packages (1.4.0)

# %%
from gym import Env
from gym.spaces import Box
import numpy as np
import matplotlib.pyplot as plt
from gym.utils import seeding
from IPython.display import clear_output
from scipy.fft import fft, ifft
from scipy.interpolate import interp1d
from scipy.io import loadmat,savemat
from maddpg import MADDPG
from buffer import MultiAgentReplayBuffer

# %%
def obs_list_to_state_vector(observation):
    state = np.array([])
    for obs in observation:
        state = np.concatenate([state, obs])
    return state

# %%
if __name__ == '__main__':
    #scenario = 'simple'
    scenario = 'simple_adversary'
    env = make_env(scenario)
    n_agents = env.n
    actor_dims = []
    for i in range(n_agents):
        actor_dims.append(env.observation_space[i].shape[0])
    critic_dims = sum(actor_dims)

    # action space is a list of arrays, assume each agent has same action space
    n_actions = env.action_space[0].n
    maddpg_agents = MADDPG(actor_dims, critic_dims, n_agents, n_actions, 
                           fc1=64, fc2=64,  
                           alpha=0.01, beta=0.01, scenario=scenario,
                           chkpt_dir='tmp/maddpg/')

    memory = MultiAgentReplayBuffer(1000000, critic_dims, actor_dims, 
                        n_actions, n_agents, batch_size=1024)

    PRINT_INTERVAL = 500
    N_GAMES = 50000
    MAX_STEPS = 25
    total_steps = 0
    score_history = []
    evaluate = False
    best_score = 0

    if evaluate:
        maddpg_agents.load_checkpoint()

    for i in range(N_GAMES):
        obs = env.reset()
        score = 0
        done = [False]*n_agents
        episode_step = 0
        while not any(done):
            if evaluate:
                env.render()
                #time.sleep(0.1) # to slow down the action for the video
            actions = maddpg_agents.choose_action(obs)
            obs_, reward, done, info = env.step(actions)

            state = obs_list_to_state_vector(obs)
            state_ = obs_list_to_state_vector(obs_)

            if episode_step >= MAX_STEPS:
                done = [True]*n_agents

            memory.store_transition(obs, state, actions, reward, obs_, state_, done)

            if total_steps % 100 == 0 and not evaluate:
                maddpg_agents.learn(memory)

            obs = obs_

            score += sum(reward)
            total_steps += 1
            episode_step += 1

        score_history.append(score)
        avg_score = np.mean(score_history[-100:])
        if not evaluate:
            if avg_score > best_score:
                maddpg_agents.save_checkpoint()
                best_score = avg_score
        if i % PRINT_INTERVAL == 0 and i > 0:
            print('episode', i, 'average score {:.1f}'.format(avg_score))
# Out:
# Streaming output truncated to the last 5000 lines.
# saved eps_2190
# episode 2190 score0.8 average score -2.2 best score 1.75
# saved eps_2191
# episode 2191 score-1.5 average score -2.1 best score 1.75
# saved eps_2192
# episode 2192 score-1.8 average score -2.2 best score 1.75
# saved eps_2193
# episode 2193 score0.4 average score -2.1 best score 1.75
# saved eps_2194
# episode 2194 score-0.9 average score -2.1 best score 1.75
# saved eps_2195
# episode 2195 score-4.6 average score -2.1 best score 1.75
# saved eps_2196
# episode 2196 score-4.1 average score -2.1 best score 1.75
# saved eps_2197
# episode 2197 score-1.6 average score -2.1 best score 1.75
# saved eps_2198
# episode 2198 score-0.5 average score -2.2 best score 1.75
# saved eps_2199
# episode 2199 score-11.0 average score -2.2 best score 1.75
# saved eps_2200
# episode 2200 score-3.7 average score -2.2 best score 1.75
# saved eps_2201
# episode 2201 score-3.6 average score -2.2 best score 1.75
# saved eps_2202
# episode 2202 score-7.2 average score -2.1 best score 1.75
# saved eps_2203
# episode 2203 score0.4 average score -2.0 best score 1.75
# saved eps_2204
# episode 2204 score-5.0 average score -2.1 best score 1.75
# saved eps_2205
# episode 2205 score-7.6 average score -2.1 best score 1.75
# saved eps_2206
# episode 2206 score-6.2 average score -2.1 best score 1.75
# saved eps_2207
# episode 2207 score-6.4 average score -2.1 best score 1.75
# saved eps_2208
# episode 2208 score-3.1 average score -2.1 best score 1.75
# saved eps_2209
# episode 2209 score-1.7 average score -2.1 best score 1.75
# saved eps_2210
# episode 2210 score-1.7 average score -2.1 best score 1.75
# saved eps_2211
# episode 2211 score-0.8 average score -2.1 best score 1.75
# saved eps_2212
# episode 2212 score-9.5 average score -2.2 best score 1.75
# saved eps_2213
# episode 2213 score-0.8 average score -2.3 best score 1.75
# saved eps_2214
# episode 2214 score-4.0 average score -2.3 best score 1.75
# saved eps_2215
# episode 2215 score2.0 average score -2.2 best score 1.75
# saved eps_2216
# episode 2216 score-2.3 average score -2.2 best score 1.75
# saved eps_2217
# episode 2217 score-3.4 average score -2.3 best score 1.75
# saved eps_2218
# episode 2218 score-5.7 average score -2.3 best score 1.75
# saved eps_2219
# episode 2219 score-2.3 average score -2.4 best score 1.75
# saved eps_2220
# episode 2220 score-3.5 average score -2.3 best score 1.75
# saved eps_2221
# episode 2221 score3.6 average score -2.2 best score 1.75
# saved eps_2222
# episode 2222 score-0.4 average score -2.2 best score 1.75
# saved eps_2223
# episode 2223 score-12.6 average score -2.3 best score 1.75
# saved eps_2224
# episode 2224 score-1.1 average score -2.3 best score 1.75
# saved eps_2225
# episode 2225 score0.4 average score -2.2 best score 1.75
# saved eps_2226
# episode 2226 score-8.7 average score -2.3 best score 1.75
# saved eps_2227
# episode 2227 score-4.4 average score -2.4 best score 1.75
# saved eps_2228
# episode 2228 score-6.1 average score -2.4 best score 1.75
# saved eps_2229
# episode 2229 score-9.4 average score -2.5 best score 1.75
# saved eps_2230
# episode 2230 score-2.1 average score -2.5 best score 1.75
# saved eps_2231
# episode 2231 score-4.1 average score -2.5 best score 1.75
# saved eps_2232
# episode 2232 score-1.8 average score -2.6 best score 1.75
# saved eps_2233
# episode 2233 score-2.4 average score -2.6 best score 1.75
# saved eps_2234
# episode 2234 score-10.0 average score -2.6 best score 1.75
# saved eps_2235
# episode 2235 score-3.2 average score -2.6 best score 1.75
# saved eps_2236
# episode 2236 score-1.1 average score -2.7 best score 1.75
# saved eps_2237
# episode 2237 score3.4 average score -2.6 best score 1.75
# saved eps_2238
# episode 2238 score-2.4 average score -2.6 best score 1.75
# saved eps_2239
# episode 2239 score-2.8 average score -2.7 best score 1.75
# saved eps_2240
# episode 2240 score-6.1 average score -2.7 best score 1.75
# saved eps_2241
# episode 2241 score-0.6 average score -2.7 best score 1.75
# saved eps_2242
# episode 2242 score-4.4 average score -2.7 best score 1.75
# saved eps_2243
# episode 2243 score-11.2 average score -2.8 best score 1.75
# saved eps_2244
# episode 2244 score-5.2 average score -2.8 best score 1.75
# saved eps_2245
# episode 2245 score-2.9 average score -2.9 best score 1.75
# saved eps_2246
# episode 2246 score-8.5 average score -2.9 best score 1.75
# saved eps_2247
# episode 2247 score-3.2 average score -2.9 best score 1.75
# saved eps_2248
# episode 2248 score-4.3 average score -3.0 best score 1.75
# saved eps_2249
# episode 2249 score-2.4 average score -3.0 best score 1.75
# saved eps_2250
# episode 2250 score-2.9 average score -3.0 best score 1.75
# saved eps_2251
# episode 2251 score-2.2 average score -3.0 best score 1.75
# saved eps_2252
# episode 2252 score-11.9 average score -3.1 best score 1.75
# saved eps_2253
# episode 2253 score2.8 average score -3.1 best score 1.75
# saved eps_2254
# episode 2254 score3.7 average score -3.0 best score 1.75
# saved eps_2255
# episode 2255 score-6.3 average score -3.1 best score 1.75
# saved eps_2256
# episode 2256 score5.1 average score -3.0 best score 1.75
# saved eps_2257
# episode 2257 score0.8 average score -3.0 best score 1.75
# saved eps_2258
# episode 2258 score-7.6 average score -3.0 best score 1.75
# saved eps_2259
# episode 2259 score-12.8 average score -3.2 best score 1.75
# saved eps_2260
# episode 2260 score-5.4 average score -3.2 best score 1.75
# saved eps_2261
# episode 2261 score-2.4 average score -3.2 best score 1.75
# saved eps_2262
# episode 2262 score1.1 average score -3.2 best score 1.75
# saved eps_2263
# episode 2263 score-1.8 average score -3.2 best score 1.75
# saved eps_2264
# episode 2264 score0.6 average score -3.2 best score 1.75
# saved eps_2265
# episode 2265 score-4.0 average score -3.2 best score 1.75
# saved eps_2266
# episode 2266 score-0.7 average score -3.2 best score 1.75
# saved eps_2267
# episode 2267 score-1.9 average score -3.2 best score 1.75
# saved eps_2268
# episode 2268 score-0.7 average score -3.2 best score 1.75
# saved eps_2269
# episode 2269 score1.1 average score -3.2 best score 1.75
# saved eps_2270
# episode 2270 score3.5 average score -3.1 best score 1.75
# saved eps_2271
# episode 2271 score-13.9 average score -3.2 best score 1.75
# saved eps_2272
# episode 2272 score-7.3 average score -3.2 best score 1.75
# saved eps_2273
# episode 2273 score-1.0 average score -3.3 best score 1.75
# saved eps_2274
# episode 2274 score-3.6 average score -3.4 best score 1.75
# saved eps_2275
# episode 2275 score-2.2 average score -3.3 best score 1.75
# saved eps_2276
# episode 2276 score-1.0 average score -3.3 best score 1.75
# saved eps_2277
# episode 2277 score-4.4 average score -3.3 best score 1.75
# saved eps_2278
# episode 2278 score-0.7 average score -3.2 best score 1.75
# saved eps_2279
# episode 2279 score-1.5 average score -3.3 best score 1.75
# saved eps_2280
# episode 2280 score-0.9 average score -3.2 best score 1.75
# saved eps_2281
# episode 2281 score-2.9 average score -3.2 best score 1.75
# saved eps_2282
# episode 2282 score-1.9 average score -3.2 best score 1.75
# saved eps_2283
# episode 2283 score0.7 average score -3.1 best score 1.75
# saved eps_2284
# episode 2284 score-9.5 average score -3.2 best score 1.75
# saved eps_2285
# episode 2285 score0.6 average score -3.2 best score 1.75
# saved eps_2286
# episode 2286 score-7.6 average score -3.2 best score 1.75
# saved eps_2287
# episode 2287 score-1.1 average score -3.2 best score 1.75
# saved eps_2288
# episode 2288 score-3.7 average score -3.2 best score 1.75
# saved eps_2289
# episode 2289 score-7.0 average score -3.3 best score 1.75
# saved eps_2290
# episode 2290 score2.3 average score -3.2 best score 1.75
# saved eps_2291
# episode 2291 score-1.7 average score -3.2 best score 1.75
# saved eps_2292
# episode 2292 score-5.0 average score -3.3 best score 1.75
# saved eps_2293
# episode 2293 score-5.4 average score -3.3 best score 1.75
# saved eps_2294
# episode 2294 score0.7 average score -3.3 best score 1.75
# saved eps_2295
# episode 2295 score-1.6 average score -3.3 best score 1.75
# saved eps_2296
# episode 2296 score-7.5 average score -3.3 best score 1.75
# saved eps_2297
# episode 2297 score-3.4 average score -3.3 best score 1.75
# saved eps_2298
# episode 2298 score-4.9 average score -3.4 best score 1.75
# saved eps_2299
# episode 2299 score-0.8 average score -3.3 best score 1.75
# saved eps_2300
# episode 2300 score-0.8 average score -3.3 best score 1.75
# saved eps_2301
# episode 2301 score-5.1 average score -3.3 best score 1.75
# saved eps_2302
# episode 2302 score-2.3 average score -3.2 best score 1.75
# saved eps_2303
# episode 2303 score-0.4 average score -3.2 best score 1.75
# saved eps_2304
# episode 2304 score-0.8 average score -3.2 best score 1.75
# saved eps_2305
# episode 2305 score4.0 average score -3.1 best score 1.75
# saved eps_2306
# episode 2306 score-1.7 average score -3.0 best score 1.75
# saved eps_2307
# episode 2307 score2.5 average score -2.9 best score 1.75
# saved eps_2308
# episode 2308 score-3.7 average score -2.9 best score 1.75
# saved eps_2309
# episode 2309 score-1.1 average score -2.9 best score 1.75
# saved eps_2310
# episode 2310 score-1.3 average score -2.9 best score 1.75
# saved eps_2311
# episode 2311 score1.2 average score -2.9 best score 1.75
# saved eps_2312
# episode 2312 score-1.4 average score -2.8 best score 1.75
# saved eps_2313
# episode 2313 score-9.3 average score -2.9 best score 1.75
# saved eps_2314
# episode 2314 score-4.8 average score -2.9 best score 1.75
# saved eps_2315
# episode 2315 score-3.3 average score -3.0 best score 1.75
# saved eps_2316
# episode 2316 score-5.7 average score -3.0 best score 1.75
# saved eps_2317
# episode 2317 score-9.2 average score -3.1 best score 1.75
# saved eps_2318
# episode 2318 score0.7 average score -3.0 best score 1.75
# saved eps_2319
# episode 2319 score-3.8 average score -3.0 best score 1.75
# saved eps_2320
# episode 2320 score-3.6 average score -3.0 best score 1.75
# saved eps_2321
# episode 2321 score-7.9 average score -3.1 best score 1.75
# saved eps_2322
# episode 2322 score-5.1 average score -3.2 best score 1.75
# saved eps_2323
# episode 2323 score-2.8 average score -3.1 best score 1.75
# saved eps_2324
# episode 2324 score-3.1 average score -3.1 best score 1.75
# saved eps_2325
# episode 2325 score-1.2 average score -3.1 best score 1.75
# saved eps_2326
# episode 2326 score0.7 average score -3.0 best score 1.75
# saved eps_2327
# episode 2327 score-4.1 average score -3.0 best score 1.75
# saved eps_2328
# episode 2328 score-2.8 average score -3.0 best score 1.75
# saved eps_2329
# episode 2329 score-4.3 average score -2.9 best score 1.75
# saved eps_2330
# episode 2330 score2.1 average score -2.9 best score 1.75
# saved eps_2331
# episode 2331 score3.5 average score -2.8 best score 1.75
# saved eps_2332
# episode 2332 score1.7 average score -2.8 best score 1.75
# saved eps_2333
# episode 2333 score0.9 average score -2.8 best score 1.75
# saved eps_2334
# episode 2334 score-5.2 average score -2.7 best score 1.75
# saved eps_2335
# episode 2335 score-2.7 average score -2.7 best score 1.75
# saved eps_2336
# episode 2336 score-2.6 average score -2.7 best score 1.75
# saved eps_2337
# episode 2337 score-0.4 average score -2.8 best score 1.75
# saved eps_2338
# episode 2338 score2.0 average score -2.7 best score 1.75
# saved eps_2339
# episode 2339 score-1.1 average score -2.7 best score 1.75
# saved eps_2340
# episode 2340 score-5.4 average score -2.7 best score 1.75
# saved eps_2341
# episode 2341 score-12.2 average score -2.8 best score 1.75
# saved eps_2342
# episode 2342 score-4.2 average score -2.8 best score 1.75
# saved eps_2343
# episode 2343 score-3.5 average score -2.7 best score 1.75
# saved eps_2344
# episode 2344 score-0.5 average score -2.7 best score 1.75
# saved eps_2345
# episode 2345 score0.8 average score -2.6 best score 1.75
# saved eps_2346
# episode 2346 score-2.3 average score -2.6 best score 1.75
# saved eps_2347
# episode 2347 score-2.1 average score -2.6 best score 1.75
# saved eps_2348
# episode 2348 score-3.6 average score -2.6 best score 1.75
# saved eps_2349
# episode 2349 score-2.5 average score -2.6 best score 1.75
# saved eps_2350
# episode 2350 score-6.8 average score -2.6 best score 1.75
# saved eps_2351
# episode 2351 score0.6 average score -2.6 best score 1.75
# saved eps_2352
# episode 2352 score-7.3 average score -2.5 best score 1.75
# saved eps_2353
# episode 2353 score-9.9 average score -2.6 best score 1.75
# saved eps_2354
# episode 2354 score5.3 average score -2.6 best score 1.75
# saved eps_2355
# episode 2355 score-1.9 average score -2.6 best score 1.75
# saved eps_2356
# episode 2356 score-4.1 average score -2.7 best score 1.75
# saved eps_2357
# episode 2357 score-9.4 average score -2.8 best score 1.75
# saved eps_2358
# episode 2358 score1.7 average score -2.7 best score 1.75
# saved eps_2359
# episode 2359 score0.2 average score -2.6 best score 1.75
# saved eps_2360
# episode 2360 score-4.1 average score -2.5 best score 1.75
# saved eps_2361
# episode 2361 score3.0 average score -2.5 best score 1.75
# saved eps_2362
# episode 2362 score-2.1 average score -2.5 best score 1.75
# saved eps_2363
# episode 2363 score4.2 average score -2.5 best score 1.75
# saved eps_2364
# episode 2364 score1.2 average score -2.5 best score 1.75
# saved eps_2365
# episode 2365 score-0.9 average score -2.4 best score 1.75
# saved eps_2366
# episode 2366 score-1.8 average score -2.4 best score 1.75
# saved eps_2367
# episode 2367 score-6.5 average score -2.5 best score 1.75
# saved eps_2368
# episode 2368 score-7.8 average score -2.6 best score 1.75
# saved eps_2369
# episode 2369 score-1.5 average score -2.6 best score 1.75
# saved eps_2370
# episode 2370 score-4.3 average score -2.7 best score 1.75
# saved eps_2371
# episode 2371 score-10.3 average score -2.6 best score 1.75
# saved eps_2372
# episode 2372 score-2.7 average score -2.6 best score 1.75
# saved eps_2373
# episode 2373 score-2.4 average score -2.6 best score 1.75
# saved eps_2374
# episode 2374 score-3.1 average score -2.6 best score 1.75
# saved eps_2375
# episode 2375 score-2.2 average score -2.6 best score 1.75
# saved eps_2376
# episode 2376 score-2.2 average score -2.6 best score 1.75
# saved eps_2377
# episode 2377 score-2.2 average score -2.6 best score 1.75
# saved eps_2378
# episode 2378 score-4.9 average score -2.6 best score 1.75
# saved eps_2379
# episode 2379 score-2.1 average score -2.6 best score 1.75
# saved eps_2380
# episode 2380 score-4.8 average score -2.7 best score 1.75
# saved eps_2381
# episode 2381 score-4.6 average score -2.7 best score 1.75
# saved eps_2382
# episode 2382 score-2.5 average score -2.7 best score 1.75
# saved eps_2383
# episode 2383 score4.4 average score -2.6 best score 1.75
# saved eps_2384
# episode 2384 score-0.3 average score -2.6 best score 1.75
# saved eps_2385
# episode 2385 score-1.6 average score -2.6 best score 1.75
# saved eps_2386
# episode 2386 score-1.3 average score -2.5 best score 1.75
# saved eps_2387
# episode 2387 score-1.3 average score -2.5 best score 1.75
# saved eps_2388
# episode 2388 score-6.0 average score -2.5 best score 1.75
# saved eps_2389
# episode 2389 score-2.3 average score -2.5 best score 1.75
# saved eps_2390
# episode 2390 score-1.1 average score -2.5 best score 1.75
# saved eps_2391
# episode 2391 score-6.4 average score -2.6 best score 1.75
# saved eps_2392
# episode 2392 score-1.2 average score -2.5 best score 1.75
# saved eps_2393
# episode 2393 score-1.2 average score -2.5 best score 1.75
# saved eps_2394
# episode 2394 score-0.2 average score -2.5 best score 1.75
# saved eps_2395
# episode 2395 score-4.2 average score -2.5 best score 1.75
# saved eps_2396
# episode 2396 score-3.4 average score -2.5 best score 1.75
# saved eps_2397
# episode 2397 score-1.6 average score -2.5 best score 1.75
# saved eps_2398
# episode 2398 score-0.4 average score -2.4 best score 1.75
# saved eps_2399
# episode 2399 score-12.9 average score -2.5 best score 1.75
# saved eps_2400
# episode 2400 score-1.7 average score -2.6 best score 1.75
# saved eps_2401
# episode 2401 score-3.2 average score -2.5 best score 1.75
# saved eps_2402
# episode 2402 score-7.6 average score -2.6 best score 1.75
# saved eps_2403
# episode 2403 score-2.0 average score -2.6 best score 1.75
# saved eps_2404
# episode 2404 score-3.4 average score -2.6 best score 1.75
# saved eps_2405
# episode 2405 score1.5 average score -2.7 best score 1.75
# saved eps_2406
# episode 2406 score-1.8 average score -2.7 best score 1.75
# saved eps_2407
# episode 2407 score-3.6 average score -2.7 best score 1.75
# saved eps_2408
# episode 2408 score-8.4 average score -2.8 best score 1.75
# saved eps_2409
# episode 2409 score2.4 average score -2.7 best score 1.75
# saved eps_2410
# episode 2410 score-0.7 average score -2.7 best score 1.75
# saved eps_2411
# episode 2411 score-11.5 average score -2.9 best score 1.75
# saved eps_2412
# episode 2412 score-2.5 average score -2.9 best score 1.75
# saved eps_2413
# episode 2413 score-0.4 average score -2.8 best score 1.75
# saved eps_2414
# episode 2414 score-1.0 average score -2.7 best score 1.75
# saved eps_2415
# episode 2415 score-1.6 average score -2.7 best score 1.75
# saved eps_2416
# episode 2416 score-4.8 average score -2.7 best score 1.75
# saved eps_2417
# episode 2417 score-1.1 average score -2.6 best score 1.75
# saved eps_2418
# episode 2418 score-7.0 average score -2.7 best score 1.75
# saved eps_2419
# episode 2419 score-3.5 average score -2.7 best score 1.75
# saved eps_2420
# episode 2420 score-0.5 average score -2.7 best score 1.75
# saved eps_2421
# episode 2421 score-0.7 average score -2.6 best score 1.75
# saved eps_2422
# episode 2422 score-2.4 average score -2.6 best score 1.75
# saved eps_2423
# episode 2423 score-0.3 average score -2.5 best score 1.75
# saved eps_2424
# episode 2424 score1.0 average score -2.5 best score 1.75
# saved eps_2425
# episode 2425 score-2.0 average score -2.5 best score 1.75
# saved eps_2426
# episode 2426 score-3.4 average score -2.6 best score 1.75
# saved eps_2427
# episode 2427 score-3.0 average score -2.5 best score 1.75
# saved eps_2428
# episode 2428 score-4.0 average score -2.6 best score 1.75
# saved eps_2429
# episode 2429 score0.3 average score -2.5 best score 1.75
# saved eps_2430
# episode 2430 score4.1 average score -2.5 best score 1.75
# saved eps_2431
# episode 2431 score1.3 average score -2.5 best score 1.75
# saved eps_2432
# episode 2432 score-2.0 average score -2.6 best score 1.75
# saved eps_2433
# episode 2433 score-0.1 average score -2.6 best score 1.75
# saved eps_2434
# episode 2434 score-1.5 average score -2.5 best score 1.75
# saved eps_2435
# episode 2435 score-3.3 average score -2.5 best score 1.75
# saved eps_2436
# episode 2436 score-2.7 average score -2.5 best score 1.75
# saved eps_2437
# episode 2437 score3.7 average score -2.5 best score 1.75
# saved eps_2438
# episode 2438 score-1.3 average score -2.5 best score 1.75
# saved eps_2439
# episode 2439 score-0.1 average score -2.5 best score 1.75
# saved eps_2440
# episode 2440 score-1.0 average score -2.5 best score 1.75
# saved eps_2441
# episode 2441 score-7.1 average score -2.4 best score 1.75
# saved eps_2442
# episode 2442 score0.5 average score -2.4 best score 1.75
# saved eps_2443
# episode 2443 score-10.1 average score -2.4 best score 1.75
# saved eps_2444
# episode 2444 score-9.3 average score -2.5 best score 1.75
# saved eps_2445
# episode 2445 score-4.8 average score -2.6 best score 1.75
# saved eps_2446
# episode 2446 score-1.2 average score -2.6 best score 1.75
# saved eps_2447
# episode 2447 score0.9 average score -2.5 best score 1.75
# saved eps_2448
# episode 2448 score-1.5 average score -2.5 best score 1.75
# saved eps_2449
# episode 2449 score-2.1 average score -2.5 best score 1.75
# saved eps_2450
# episode 2450 score-4.4 average score -2.5 best score 1.75
# saved eps_2451
# episode 2451 score-4.7 average score -2.5 best score 1.75
# saved eps_2452
# episode 2452 score-1.4 average score -2.5 best score 1.75
# saved eps_2453
# episode 2453 score-6.0 average score -2.4 best score 1.75
# saved eps_2454
# episode 2454 score0.4 average score -2.5 best score 1.75
# saved eps_2455
# episode 2455 score-5.5 average score -2.5 best score 1.75
# saved eps_2456
# episode 2456 score-12.3 average score -2.6 best score 1.75
# saved eps_2457
# episode 2457 score-2.0 average score -2.5 best score 1.75
# saved eps_2458
# episode 2458 score-8.9 average score -2.6 best score 1.75
# saved eps_2459
# episode 2459 score-1.9 average score -2.7 best score 1.75
# saved eps_2460
# episode 2460 score-5.6 average score -2.7 best score 1.75
# saved eps_2461
# episode 2461 score-12.7 average score -2.8 best score 1.75
# saved eps_2462
# episode 2462 score-1.9 average score -2.8 best score 1.75
# saved eps_2463
# episode 2463 score3.9 average score -2.8 best score 1.75
# saved eps_2464
# episode 2464 score-2.6 average score -2.9 best score 1.75
# saved eps_2465
# episode 2465 score-4.7 average score -2.9 best score 1.75
# saved eps_2466
# episode 2466 score-2.3 average score -2.9 best score 1.75
# saved eps_2467
# episode 2467 score-5.5 average score -2.9 best score 1.75
# saved eps_2468
# episode 2468 score-0.7 average score -2.8 best score 1.75
# saved eps_2469
# episode 2469 score-2.9 average score -2.9 best score 1.75
# saved eps_2470
# episode 2470 score-5.4 average score -2.9 best score 1.75
# saved eps_2471
# episode 2471 score-2.7 average score -2.8 best score 1.75
# saved eps_2472
# episode 2472 score-4.2 average score -2.8 best score 1.75
# saved eps_2473
# episode 2473 score-6.4 average score -2.8 best score 1.75
# saved eps_2474
# episode 2474 score3.2 average score -2.8 best score 1.75
# saved eps_2475
# episode 2475 score-5.4 average score -2.8 best score 1.75
# saved eps_2476
# episode 2476 score-5.4 average score -2.8 best score 1.75
# saved eps_2477
# episode 2477 score-5.9 average score -2.9 best score 1.75
# saved eps_2478
# episode 2478 score0.8 average score -2.8 best score 1.75
# saved eps_2479
# episode 2479 score-6.4 average score -2.9 best score 1.75
# saved eps_2480
# episode 2480 score-0.6 average score -2.8 best score 1.75
# saved eps_2481
# episode 2481 score-1.9 average score -2.8 best score 1.75
# saved eps_2482
# episode 2482 score-0.9 average score -2.8 best score 1.75
# saved eps_2483
# episode 2483 score0.9 average score -2.8 best score 1.75
# saved eps_2484
# episode 2484 score-8.1 average score -2.9 best score 1.75
# saved eps_2485
# episode 2485 score0.7 average score -2.9 best score 1.75
# saved eps_2486
# episode 2486 score-0.0 average score -2.9 best score 1.75
# saved eps_2487
# episode 2487 score-3.8 average score -2.9 best score 1.75
# saved eps_2488
# episode 2488 score-11.4 average score -2.9 best score 1.75
# saved eps_2489
# episode 2489 score-1.2 average score -2.9 best score 1.75
# saved eps_2490
# episode 2490 score-3.6 average score -3.0 best score 1.75
# saved eps_2491
# episode 2491 score-1.8 average score -2.9 best score 1.75
# saved eps_2492
# episode 2492 score-7.3 average score -3.0 best score 1.75
# saved eps_2493
# episode 2493 score-3.3 average score -3.0 best score 1.75
# saved eps_2494
# episode 2494 score-6.9 average score -3.1 best score 1.75
# saved eps_2495
# episode 2495 score-10.3 average score -3.1 best score 1.75
# saved eps_2496
# episode 2496 score-3.4 average score -3.1 best score 1.75
# saved eps_2497
# episode 2497 score-2.2 average score -3.1 best score 1.75
# saved eps_2498
# episode 2498 score-3.9 average score -3.2 best score 1.75
# saved eps_2499
# episode 2499 score-3.7 average score -3.1 best score 1.75
# saved eps_2500
# episode 2500 score-13.7 average score -3.2 best score 1.75
# saved eps_2501
# episode 2501 score-0.2 average score -3.2 best score 1.75
# saved eps_2502
# episode 2502 score-2.7 average score -3.1 best score 1.75
# saved eps_2503
# episode 2503 score-9.0 average score -3.2 best score 1.75
# saved eps_2504
# episode 2504 score-12.5 average score -3.3 best score 1.75
# saved eps_2505
# episode 2505 score-5.9 average score -3.3 best score 1.75
# saved eps_2506
# episode 2506 score-0.3 average score -3.3 best score 1.75
# saved eps_2507
# episode 2507 score0.3 average score -3.3 best score 1.75
# saved eps_2508
# episode 2508 score1.8 average score -3.2 best score 1.75
# saved eps_2509
# episode 2509 score-1.7 average score -3.2 best score 1.75
# saved eps_2510
# episode 2510 score-3.2 average score -3.3 best score 1.75
# saved eps_2511
# episode 2511 score-1.4 average score -3.2 best score 1.75
# saved eps_2512
# episode 2512 score-6.5 average score -3.2 best score 1.75
# saved eps_2513
# episode 2513 score-4.2 average score -3.2 best score 1.75
# saved eps_2514
# episode 2514 score-3.7 average score -3.3 best score 1.75
# saved eps_2515
# episode 2515 score-1.8 average score -3.3 best score 1.75
# saved eps_2516
# episode 2516 score-7.6 average score -3.3 best score 1.75
# saved eps_2517
# episode 2517 score-4.6 average score -3.3 best score 1.75
# saved eps_2518
# episode 2518 score0.3 average score -3.3 best score 1.75
# saved eps_2519
# episode 2519 score-1.2 average score -3.2 best score 1.75
# saved eps_2520
# episode 2520 score3.3 average score -3.2 best score 1.75
# saved eps_2521
# episode 2521 score-5.1 average score -3.2 best score 1.75
# saved eps_2522
# episode 2522 score-8.5 average score -3.3 best score 1.75
# saved eps_2523
# episode 2523 score0.0 average score -3.3 best score 1.75
# saved eps_2524
# episode 2524 score-2.4 average score -3.3 best score 1.75
# saved eps_2525
# episode 2525 score-3.6 average score -3.3 best score 1.75
# saved eps_2526
# episode 2526 score-4.1 average score -3.4 best score 1.75
# saved eps_2527
# episode 2527 score-2.3 average score -3.3 best score 1.75
# saved eps_2528
# episode 2528 score-1.0 average score -3.3 best score 1.75
# saved eps_2529
# episode 2529 score-1.4 average score -3.3 best score 1.75
# saved eps_2530
# episode 2530 score-1.1 average score -3.4 best score 1.75
# saved eps_2531
# episode 2531 score-3.0 average score -3.4 best score 1.75
# saved eps_2532
# episode 2532 score-3.7 average score -3.4 best score 1.75
# saved eps_2533
# episode 2533 score-2.2 average score -3.5 best score 1.75
# saved eps_2534
# episode 2534 score-8.0 average score -3.5 best score 1.75
# saved eps_2535
# episode 2535 score3.4 average score -3.5 best score 1.75
# saved eps_2536
# episode 2536 score-3.9 average score -3.5 best score 1.75
# saved eps_2537
# episode 2537 score1.0 average score -3.5 best score 1.75
# saved eps_2538
# episode 2538 score-5.5 average score -3.5 best score 1.75
# saved eps_2539
# episode 2539 score-2.8 average score -3.6 best score 1.75
# saved eps_2540
# episode 2540 score-7.7 average score -3.6 best score 1.75
# saved eps_2541
# episode 2541 score-5.5 average score -3.6 best score 1.75
# saved eps_2542
# episode 2542 score-1.2 average score -3.6 best score 1.75
# saved eps_2543
# episode 2543 score-7.6 average score -3.6 best score 1.75
# saved eps_2544
# episode 2544 score1.9 average score -3.5 best score 1.75
# saved eps_2545
# episode 2545 score-0.5 average score -3.5 best score 1.75
# saved eps_2546
# episode 2546 score-10.3 average score -3.5 best score 1.75
# saved eps_2547
# episode 2547 score-3.2 average score -3.6 best score 1.75
# saved eps_2548
# episode 2548 score-1.1 average score -3.6 best score 1.75
# saved eps_2549
# episode 2549 score-13.6 average score -3.7 best score 1.75
# saved eps_2550
# episode 2550 score-4.1 average score -3.7 best score 1.75
# saved eps_2551
# episode 2551 score-3.6 average score -3.7 best score 1.75
# saved eps_2552
# episode 2552 score1.0 average score -3.7 best score 1.75
# saved eps_2553
# episode 2553 score1.1 average score -3.6 best score 1.75
# saved eps_2554
# episode 2554 score-2.1 average score -3.6 best score 1.75
# saved eps_2555
# episode 2555 score-1.2 average score -3.6 best score 1.75
# saved eps_2556
# episode 2556 score-17.2 average score -3.6 best score 1.75
# saved eps_2557
# episode 2557 score0.4 average score -3.6 best score 1.75
# saved eps_2558
# episode 2558 score-0.9 average score -3.5 best score 1.75
# saved eps_2559
# episode 2559 score-10.1 average score -3.6 best score 1.75
# saved eps_2560
# episode 2560 score2.1 average score -3.5 best score 1.75
# saved eps_2561
# episode 2561 score0.9 average score -3.4 best score 1.75
# saved eps_2562
# episode 2562 score1.9 average score -3.3 best score 1.75
# saved eps_2563
# episode 2563 score-5.8 average score -3.4 best score 1.75
# saved eps_2564
# episode 2564 score-2.0 average score -3.4 best score 1.75
# saved eps_2565
# episode 2565 score0.3 average score -3.4 best score 1.75
# saved eps_2566
# episode 2566 score-1.0 average score -3.4 best score 1.75
# saved eps_2567
# episode 2567 score2.6 average score -3.3 best score 1.75
# saved eps_2568
# episode 2568 score-3.5 average score -3.3 best score 1.75
# saved eps_2569
# episode 2569 score-8.6 average score -3.4 best score 1.75
# saved eps_2570
# episode 2570 score1.9 average score -3.3 best score 1.75
# saved eps_2571
# episode 2571 score-6.9 average score -3.4 best score 1.75
# saved eps_2572
# episode 2572 score-1.4 average score -3.3 best score 1.75
# saved eps_2573
# episode 2573 score-5.2 average score -3.3 best score 1.75
# saved eps_2574
# episode 2574 score6.4 average score -3.3 best score 1.75
# saved eps_2575
# episode 2575 score0.3 average score -3.2 best score 1.75
# saved eps_2576
# episode 2576 score-1.6 average score -3.2 best score 1.75
# saved eps_2577
# episode 2577 score0.2 average score -3.1 best score 1.75
# saved eps_2578
# episode 2578 score-2.3 average score -3.2 best score 1.75
# saved eps_2579
# episode 2579 score-5.6 average score -3.1 best score 1.75
# saved eps_2580
# episode 2580 score-1.8 average score -3.2 best score 1.75
# saved eps_2581
# episode 2581 score-0.5 average score -3.1 best score 1.75
# saved eps_2582
# episode 2582 score3.3 average score -3.1 best score 1.75
# saved eps_2583
# episode 2583 score-7.7 average score -3.2 best score 1.75
# saved eps_2584
# episode 2584 score4.1 average score -3.1 best score 1.75
# saved eps_2585
# episode 2585 score-9.4 average score -3.2 best score 1.75
# saved eps_2586
# episode 2586 score-3.8 average score -3.2 best score 1.75
# saved eps_2587
# episode 2587 score-7.6 average score -3.2 best score 1.75
# saved eps_2588
# episode 2588 score-0.4 average score -3.1 best score 1.75
# saved eps_2589
# episode 2589 score-9.2 average score -3.2 best score 1.75
# saved eps_2590
# episode 2590 score-4.3 average score -3.2 best score 1.75
# saved eps_2591
# episode 2591 score-2.7 average score -3.2 best score 1.75
# saved eps_2592
# episode 2592 score-1.3 average score -3.2 best score 1.75
# saved eps_2593
# episode 2593 score1.1 average score -3.1 best score 1.75
# saved eps_2594
# episode 2594 score0.4 average score -3.0 best score 1.75
# saved eps_2595
# episode 2595 score-5.9 average score -3.0 best score 1.75
# saved eps_2596
# episode 2596 score-1.8 average score -3.0 best score 1.75
# saved eps_2597
# episode 2597 score-4.6 average score -3.0 best score 1.75
# saved eps_2598
# episode 2598 score3.0 average score -2.9 best score 1.75
# saved eps_2599
# episode 2599 score-5.7 average score -3.0 best score 1.75
# saved eps_2600
# episode 2600 score-7.3 average score -2.9 best score 1.75
# saved eps_2601
# episode 2601 score-2.8 average score -2.9 best score 1.75
# saved eps_2602
# episode 2602 score-1.9 average score -2.9 best score 1.75
# saved eps_2603
# episode 2603 score-1.2 average score -2.8 best score 1.75
# saved eps_2604
# episode 2604 score-0.7 average score -2.7 best score 1.75
# saved eps_2605
# episode 2605 score-2.6 average score -2.7 best score 1.75
# saved eps_2606
# episode 2606 score-2.2 average score -2.7 best score 1.75
# saved eps_2607
# episode 2607 score-8.3 average score -2.8 best score 1.75
# saved eps_2608
# episode 2608 score-8.2 average score -2.9 best score 1.75
# saved eps_2609
# episode 2609 score-3.4 average score -2.9 best score 1.75
# saved eps_2610
# episode 2610 score-1.8 average score -2.9 best score 1.75
# saved eps_2611
# episode 2611 score-6.7 average score -2.9 best score 1.75
# saved eps_2612
# episode 2612 score-6.9 average score -3.0 best score 1.75
# saved eps_2613
# episode 2613 score0.7 average score -2.9 best score 1.75
# saved eps_2614
# episode 2614 score0.4 average score -2.9 best score 1.75
# saved eps_2615
# episode 2615 score-5.3 average score -2.9 best score 1.75
# saved eps_2616
# episode 2616 score-3.1 average score -2.9 best score 1.75
# saved eps_2617
# episode 2617 score-4.5 average score -2.9 best score 1.75
# saved eps_2618
# episode 2618 score-1.7 average score -2.9 best score 1.75
# saved eps_2619
# episode 2619 score0.4 average score -2.9 best score 1.75
# saved eps_2620
# episode 2620 score3.7 average score -2.9 best score 1.75
# saved eps_2621
# episode 2621 score7.0 average score -2.7 best score 1.75
# saved eps_2622
# episode 2622 score-1.3 average score -2.7 best score 1.75
# saved eps_2623
# episode 2623 score-1.4 average score -2.7 best score 1.75
# saved eps_2624
# episode 2624 score0.2 average score -2.6 best score 1.75
# saved eps_2625
# episode 2625 score-2.4 average score -2.6 best score 1.75
# saved eps_2626
# episode 2626 score0.2 average score -2.6 best score 1.75
# saved eps_2627
# episode 2627 score-2.5 average score -2.6 best score 1.75
# saved eps_2628
# episode 2628 score0.8 average score -2.6 best score 1.75
# saved eps_2629
# episode 2629 score-6.5 average score -2.6 best score 1.75
# saved eps_2630
# episode 2630 score-3.4 average score -2.7 best score 1.75
# saved eps_2631
# episode 2631 score-3.8 average score -2.7 best score 1.75
# saved eps_2632
# episode 2632 score-3.8 average score -2.7 best score 1.75
# saved eps_2633
# episode 2633 score-5.3 average score -2.7 best score 1.75
# saved eps_2634
# episode 2634 score-2.5 average score -2.6 best score 1.75
# saved eps_2635
# episode 2635 score-15.4 average score -2.8 best score 1.75
# saved eps_2636
# episode 2636 score-2.1 average score -2.8 best score 1.75
# saved eps_2637
# episode 2637 score-8.2 average score -2.9 best score 1.75
# saved eps_2638
# episode 2638 score-14.0 average score -3.0 best score 1.75
# saved eps_2639
# episode 2639 score-2.4 average score -3.0 best score 1.75
# saved eps_2640
# episode 2640 score-2.5 average score -2.9 best score 1.75
# saved eps_2641
# episode 2641 score-3.4 average score -2.9 best score 1.75
# saved eps_2642
# episode 2642 score-1.9 average score -2.9 best score 1.75
# saved eps_2643
# episode 2643 score-2.9 average score -2.9 best score 1.75
# saved eps_2644
# episode 2644 score-1.9 average score -2.9 best score 1.75
# saved eps_2645
# episode 2645 score-1.6 average score -2.9 best score 1.75
# saved eps_2646
# episode 2646 score-1.1 average score -2.8 best score 1.75
# saved eps_2647
# episode 2647 score-1.0 average score -2.8 best score 1.75
# saved eps_2648
# episode 2648 score-2.6 average score -2.8 best score 1.75
# saved eps_2649
# episode 2649 score-5.7 average score -2.7 best score 1.75
# saved eps_2650
# episode 2650 score0.8 average score -2.7 best score 1.75
# saved eps_2651
# episode 2651 score-6.4 average score -2.7 best score 1.75
# saved eps_2652
# episode 2652 score2.0 average score -2.7 best score 1.75
# saved eps_2653
# episode 2653 score1.6 average score -2.7 best score 1.75
# saved eps_2654
# episode 2654 score-2.6 average score -2.7 best score 1.75
# saved eps_2655
# episode 2655 score2.0 average score -2.7 best score 1.75
# saved eps_2656
# episode 2656 score-3.3 average score -2.5 best score 1.75
# saved eps_2657
# episode 2657 score-8.0 average score -2.6 best score 1.75
# saved eps_2658
# episode 2658 score-0.3 average score -2.6 best score 1.75
# saved eps_2659
# episode 2659 score-4.1 average score -2.6 best score 1.75
# saved eps_2660
# episode 2660 score0.7 average score -2.6 best score 1.75
# saved eps_2661
# episode 2661 score-5.0 average score -2.6 best score 1.75
# saved eps_2662
# episode 2662 score-5.9 average score -2.7 best score 1.75
# saved eps_2663
# episode 2663 score-2.3 average score -2.7 best score 1.75
# saved eps_2664
# episode 2664 score-6.3 average score -2.7 best score 1.75
# saved eps_2665
# episode 2665 score-1.4 average score -2.7 best score 1.75
# saved eps_2666
# episode 2666 score-1.5 average score -2.7 best score 1.75
# saved eps_2667
# episode 2667 score2.1 average score -2.7 best score 1.75
# saved eps_2668
# episode 2668 score-5.3 average score -2.8 best score 1.75
# saved eps_2669
# episode 2669 score-1.0 average score -2.7 best score 1.75
# saved eps_2670
# episode 2670 score1.2 average score -2.7 best score 1.75
# saved eps_2671
# episode 2671 score-4.3 average score -2.7 best score 1.75
# saved eps_2672
# episode 2672 score-6.6 average score -2.7 best score 1.75
# saved eps_2673
# episode 2673 score-2.9 average score -2.7 best score 1.75
# saved eps_2674
# episode 2674 score-4.2 average score -2.8 best score 1.75
# saved eps_2675
# episode 2675 score-4.5 average score -2.8 best score 1.75
# saved eps_2676
# episode 2676 score-1.3 average score -2.8 best score 1.75
# saved eps_2677
# episode 2677 score-6.0 average score -2.9 best score 1.75
# saved eps_2678
# episode 2678 score-7.6 average score -3.0 best score 1.75
# saved eps_2679
# episode 2679 score-0.4 average score -2.9 best score 1.75
# saved eps_2680
# episode 2680 score-3.0 average score -2.9 best score 1.75
# saved eps_2681
# episode 2681 score-4.5 average score -3.0 best score 1.75
# saved eps_2682
# episode 2682 score-6.1 average score -3.1 best score 1.75
# saved eps_2683
# episode 2683 score-3.1 average score -3.0 best score 1.75
# saved eps_2684
# episode 2684 score-3.9 average score -3.1 best score 1.75
# saved eps_2685
# episode 2685 score1.3 average score -3.0 best score 1.75
# saved eps_2686
# episode 2686 score0.6 average score -2.9 best score 1.75
# saved eps_2687
# episode 2687 score-3.6 average score -2.9 best score 1.75
# saved eps_2688
# episode 2688 score-13.6 average score -3.0 best score 1.75
# saved eps_2689
# episode 2689 score-3.5 average score -3.0 best score 1.75
# saved eps_2690
# episode 2690 score-2.5 average score -3.0 best score 1.75
# saved eps_2691
# episode 2691 score-4.0 average score -3.0 best score 1.75
# saved eps_2692
# episode 2692 score-2.6 average score -3.0 best score 1.75
# saved eps_2693
# episode 2693 score-2.3 average score -3.0 best score 1.75
# saved eps_2694
# episode 2694 score-0.5 average score -3.0 best score 1.75
# saved eps_2695
# episode 2695 score-2.3 average score -3.0 best score 1.75
# saved eps_2696
# episode 2696 score-9.6 average score -3.1 best score 1.75
# saved eps_2697
# episode 2697 score-3.1 average score -3.1 best score 1.75
# saved eps_2698
# episode 2698 score-5.4 average score -3.1 best score 1.75
# saved eps_2699
# episode 2699 score-0.7 average score -3.1 best score 1.75
# saved eps_2700
# episode 2700 score-9.2 average score -3.1 best score 1.75
# saved eps_2701
# episode 2701 score-6.2 average score -3.1 best score 1.75
# saved eps_2702
# episode 2702 score-2.0 average score -3.1 best score 1.75
# saved eps_2703
# episode 2703 score-3.2 average score -3.2 best score 1.75
# saved eps_2704
# episode 2704 score-3.3 average score -3.2 best score 1.75
# saved eps_2705
# episode 2705 score-2.6 average score -3.2 best score 1.75
# saved eps_2706
# episode 2706 score-0.7 average score -3.2 best score 1.75
# saved eps_2707
# episode 2707 score-8.7 average score -3.2 best score 1.75
# saved eps_2708
# episode 2708 score-5.0 average score -3.1 best score 1.75
# saved eps_2709
# episode 2709 score-3.6 average score -3.1 best score 1.75
# saved eps_2710
# episode 2710 score0.9 average score -3.1 best score 1.75
# saved eps_2711
# episode 2711 score-2.0 average score -3.1 best score 1.75
# saved eps_2712
# episode 2712 score0.2 average score -3.0 best score 1.75
# saved eps_2713
# episode 2713 score-4.6 average score -3.1 best score 1.75
# saved eps_2714
# episode 2714 score-2.0 average score -3.1 best score 1.75
# saved eps_2715
# episode 2715 score-2.9 average score -3.1 best score 1.75
# saved eps_2716
# episode 2716 score-13.9 average score -3.2 best score 1.75
# saved eps_2717
# episode 2717 score-0.4 average score -3.1 best score 1.75
# saved eps_2718
# episode 2718 score-6.5 average score -3.2 best score 1.75
# saved eps_2719
# episode 2719 score0.2 average score -3.2 best score 1.75
# saved eps_2720
# episode 2720 score0.4 average score -3.2 best score 1.75
# saved eps_2721
# episode 2721 score-1.6 average score -3.3 best score 1.75
# saved eps_2722
# episode 2722 score3.6 average score -3.2 best score 1.75
# saved eps_2723
# episode 2723 score-4.2 average score -3.3 best score 1.75
# saved eps_2724
# episode 2724 score-1.2 average score -3.3 best score 1.75
# saved eps_2725
# episode 2725 score-9.6 average score -3.4 best score 1.75
# saved eps_2726
# episode 2726 score-2.5 average score -3.4 best score 1.75
# saved eps_2727
# episode 2727 score3.8 average score -3.3 best score 1.75
# saved eps_2728
# episode 2728 score3.6 average score -3.3 best score 1.75
# saved eps_2729
# episode 2729 score-4.5 average score -3.3 best score 1.75
# saved eps_2730
# episode 2730 score-0.7 average score -3.2 best score 1.75
# saved eps_2731
# episode 2731 score1.3 average score -3.2 best score 1.75
# saved eps_2732
# episode 2732 score-4.1 average score -3.2 best score 1.75
# saved eps_2733
# episode 2733 score-3.7 average score -3.2 best score 1.75
# saved eps_2734
# episode 2734 score-3.8 average score -3.2 best score 1.75
# saved eps_2735
# episode 2735 score1.1 average score -3.0 best score 1.75
# saved eps_2736
# episode 2736 score-1.5 average score -3.0 best score 1.75
# saved eps_2737
# episode 2737 score-2.3 average score -3.0 best score 1.75
# saved eps_2738
# episode 2738 score-8.7 average score -2.9 best score 1.75
# saved eps_2739
# episode 2739 score-5.3 average score -2.9 best score 1.75
# saved eps_2740
# episode 2740 score-1.2 average score -2.9 best score 1.75
# saved eps_2741
# episode 2741 score-4.1 average score -2.9 best score 1.75
# saved eps_2742
# episode 2742 score-5.6 average score -3.0 best score 1.75
# saved eps_2743
# episode 2743 score-1.7 average score -3.0 best score 1.75
# saved eps_2744
# episode 2744 score-0.3 average score -2.9 best score 1.75
# saved eps_2745
# episode 2745 score-3.5 average score -3.0 best score 1.75
# saved eps_2746
# episode 2746 score1.1 average score -2.9 best score 1.75
# saved eps_2747
# episode 2747 score-4.2 average score -3.0 best score 1.75
# saved eps_2748
# episode 2748 score-11.8 average score -3.1 best score 1.75
# saved eps_2749
# episode 2749 score-4.9 average score -3.1 best score 1.75
# saved eps_2750
# episode 2750 score-9.3 average score -3.2 best score 1.75
# saved eps_2751
# episode 2751 score-1.9 average score -3.1 best score 1.75
# saved eps_2752
# episode 2752 score-11.0 average score -3.2 best score 1.75
# saved eps_2753
# episode 2753 score-0.2 average score -3.3 best score 1.75
# saved eps_2754
# episode 2754 score-0.9 average score -3.2 best score 1.75
# saved eps_2755
# episode 2755 score-8.5 average score -3.3 best score 1.75
# saved eps_2756
# episode 2756 score-1.0 average score -3.3 best score 1.75
# saved eps_2757
# episode 2757 score-3.5 average score -3.3 best score 1.75
# saved eps_2758
# episode 2758 score-2.6 average score -3.3 best score 1.75
# saved eps_2759
# episode 2759 score-9.2 average score -3.4 best score 1.75
# saved eps_2760
# episode 2760 score0.1 average score -3.4 best score 1.75
# saved eps_2761
# episode 2761 score-4.8 average score -3.4 best score 1.75
# saved eps_2762
# episode 2762 score-4.3 average score -3.3 best score 1.75
# saved eps_2763
# episode 2763 score-3.7 average score -3.4 best score 1.75
# saved eps_2764
# episode 2764 score-7.4 average score -3.4 best score 1.75
# saved eps_2765
# episode 2765 score-5.9 average score -3.4 best score 1.75
# saved eps_2766
# episode 2766 score-4.3 average score -3.4 best score 1.75
# saved eps_2767
# episode 2767 score-0.3 average score -3.5 best score 1.75
# saved eps_2768
# episode 2768 score-4.5 average score -3.5 best score 1.75
# saved eps_2769
# episode 2769 score-4.0 average score -3.5 best score 1.75
# saved eps_2770
# episode 2770 score-2.0 average score -3.5 best score 1.75
# saved eps_2771
# episode 2771 score-1.7 average score -3.5 best score 1.75
# saved eps_2772
# episode 2772 score-9.2 average score -3.5 best score 1.75
# saved eps_2773
# episode 2773 score-0.4 average score -3.5 best score 1.75
# saved eps_2774
# episode 2774 score-3.0 average score -3.5 best score 1.75
# saved eps_2775
# episode 2775 score-4.8 average score -3.5 best score 1.75
# saved eps_2776
# episode 2776 score-3.7 average score -3.5 best score 1.75
# saved eps_2777
# episode 2777 score-4.4 average score -3.5 best score 1.75
# saved eps_2778
# episode 2778 score-6.9 average score -3.5 best score 1.75
# saved eps_2779
# episode 2779 score-3.0 average score -3.5 best score 1.75
# saved eps_2780
# episode 2780 score-4.0 average score -3.5 best score 1.75
# saved eps_2781
# episode 2781 score-6.8 average score -3.5 best score 1.75
# saved eps_2782
# episode 2782 score-0.7 average score -3.5 best score 1.75
# saved eps_2783
# episode 2783 score-1.6 average score -3.5 best score 1.75
# saved eps_2784
# episode 2784 score-12.3 average score -3.6 best score 1.75
# saved eps_2785
# episode 2785 score0.8 average score -3.6 best score 1.75
# saved eps_2786
# episode 2786 score-11.6 average score -3.7 best score 1.75
# saved eps_2787
# episode 2787 score-2.6 average score -3.7 best score 1.75
# saved eps_2788
# episode 2788 score-6.0 average score -3.6 best score 1.75
# saved eps_2789
# episode 2789 score-2.5 average score -3.6 best score 1.75
# saved eps_2790
# episode 2790 score-9.4 average score -3.7 best score 1.75
# saved eps_2791
# episode 2791 score-7.5 average score -3.7 best score 1.75
# saved eps_2792
# episode 2792 score-4.1 average score -3.7 best score 1.75
# saved eps_2793
# episode 2793 score-2.7 average score -3.7 best score 1.75
# saved eps_2794
# episode 2794 score-1.9 average score -3.7 best score 1.75
# saved eps_2795
# episode 2795 score1.0 average score -3.7 best score 1.75
# saved eps_2796
# episode 2796 score-2.8 average score -3.6 best score 1.75
# saved eps_2797
# episode 2797 score-1.3 average score -3.6 best score 1.75
# saved eps_2798
# episode 2798 score-1.5 average score -3.6 best score 1.75
# saved eps_2799
# episode 2799 score-2.9 average score -3.6 best score 1.75
# saved eps_2800
# episode 2800 score-5.1 average score -3.6 best score 1.75
# saved eps_2801
# episode 2801 score0.7 average score -3.5 best score 1.75
# saved eps_2802
# episode 2802 score-2.0 average score -3.5 best score 1.75
# saved eps_2803
# episode 2803 score-4.6 average score -3.5 best score 1.75
# saved eps_2804
# episode 2804 score-2.0 average score -3.5 best score 1.75
# saved eps_2805
# episode 2805 score-5.6 average score -3.5 best score 1.75
# saved eps_2806
# episode 2806 score-4.7 average score -3.6 best score 1.75
# saved eps_2807
# episode 2807 score-10.3 average score -3.6 best score 1.75
# saved eps_2808
# episode 2808 score-7.1 average score -3.6 best score 1.75
# saved eps_2809
# episode 2809 score-1.3 average score -3.6 best score 1.75
# saved eps_2810
# episode 2810 score-3.5 average score -3.6 best score 1.75
# saved eps_2811
# episode 2811 score-3.7 average score -3.6 best score 1.75
# saved eps_2812
# episode 2812 score1.6 average score -3.6 best score 1.75
# saved eps_2813
# episode 2813 score-4.8 average score -3.6 best score 1.75
# saved eps_2814
# episode 2814 score0.7 average score -3.6 best score 1.75
# saved eps_2815
# episode 2815 score-12.7 average score -3.7 best score 1.75
# saved eps_2816
# episode 2816 score-3.4 average score -3.6 best score 1.75
# saved eps_2817
# episode 2817 score-9.4 average score -3.7 best score 1.75
# saved eps_2818
# episode 2818 score-5.7 average score -3.7 best score 1.75
# saved eps_2819
# episode 2819 score-17.3 average score -3.8 best score 1.75
# saved eps_2820
# episode 2820 score-6.5 average score -3.9 best score 1.75
# saved eps_2821
# episode 2821 score0.1 average score -3.9 best score 1.75
# saved eps_2822
# episode 2822 score-3.6 average score -4.0 best score 1.75
# saved eps_2823
# episode 2823 score-4.5 average score -4.0 best score 1.75
# saved eps_2824
# episode 2824 score-6.0 average score -4.0 best score 1.75
# saved eps_2825
# episode 2825 score0.1 average score -3.9 best score 1.75
# saved eps_2826
# episode 2826 score-3.4 average score -3.9 best score 1.75
# saved eps_2827
# episode 2827 score-3.2 average score -4.0 best score 1.75
# saved eps_2828
# episode 2828 score-6.6 average score -4.1 best score 1.75
# saved eps_2829
# episode 2829 score-0.8 average score -4.1 best score 1.75
# saved eps_2830
# episode 2830 score-10.5 average score -4.2 best score 1.75
# saved eps_2831
# episode 2831 score-7.6 average score -4.2 best score 1.75
# saved eps_2832
# episode 2832 score-7.8 average score -4.3 best score 1.75
# saved eps_2833
# episode 2833 score-4.6 average score -4.3 best score 1.75
# saved eps_2834
# episode 2834 score-5.2 average score -4.3 best score 1.75
# saved eps_2835
# episode 2835 score-6.2 average score -4.4 best score 1.75
# saved eps_2836
# episode 2836 score-4.0 average score -4.4 best score 1.75
# saved eps_2837
# episode 2837 score-2.4 average score -4.4 best score 1.75
# saved eps_2838
# episode 2838 score-0.2 average score -4.3 best score 1.75
# saved eps_2839
# episode 2839 score-1.7 average score -4.3 best score 1.75
# saved eps_2840
# episode 2840 score-2.1 average score -4.3 best score 1.75
# saved eps_2841
# episode 2841 score-9.6 average score -4.3 best score 1.75
# saved eps_2842
# episode 2842 score-5.0 average score -4.3 best score 1.75
# saved eps_2843
# episode 2843 score-10.7 average score -4.4 best score 1.75
# saved eps_2844
# episode 2844 score-3.9 average score -4.5 best score 1.75
# saved eps_2845
# episode 2845 score-3.0 average score -4.5 best score 1.75
# saved eps_2846
# episode 2846 score-3.1 average score -4.5 best score 1.75
# saved eps_2847
# ...
# saved eps_4487
# episode 4487 score-4.0 average score -3.0 best score 1.75
# saved eps_4488
# episode 4488 score-4.1 average score -3.1 best score 1.75
# saved eps_4489
# episode 4489 score-7.8 average score -3.1 best score 1.75
# saved eps_4490
# episode 4490 score-0.3 average score -3.1 best score 1.75
# saved eps_4491
# episode 4491 score-6.9 average score -3.0 best score 1.75
# saved eps_4492
# episode 4492 score-7.6 average score -3.1 best score 1.75
# saved eps_4493
# episode 4493 score-5.2 average score -3.1 best score 1.75
# saved eps_4494
# episode 4494 score-5.2 average score -3.2 best score 1.75
# saved eps_4495
# episode 4495 score-9.0 average score -3.2 best score 1.75
# saved eps_4496
# episode 4496 score-5.6 average score -3.2 best score 1.75
# saved eps_4497
# episode 4497 score-3.4 average score -3.2 best score 1.75
# saved eps_4498
# episode 4498 score0.4 average score -3.2 best score 1.75
# saved eps_4499
# episode 4499 score-6.6 average score -3.3 best score 1.75
# saved eps_4500
# episode 4500 score-0.7 average score -3.2 best score 1.75
# saved eps_4501
# episode 4501 score-3.0 average score -3.2 best score 1.75
# saved eps_4502
# episode 4502 score-3.1 average score -3.2 best score 1.75
# saved eps_4503
# episode 4503 score-0.9 average score -3.2 best score 1.75
# saved eps_4504
# episode 4504 score0.4 average score -3.2 best score 1.75
# saved eps_4505
# episode 4505 score0.8 average score -3.1 best score 1.75
# saved eps_4506
# episode 4506 score2.9 average score -3.0 best score 1.75
# saved eps_4507
# episode 4507 score-2.4 average score -3.0 best score 1.75
# saved eps_4508
# episode 4508 score-2.0 average score -3.1 best score 1.75
# saved eps_4509
# episode 4509 score0.7 average score -3.0 best score 1.75
# saved eps_4510
# episode 4510 score-3.4 average score -3.0 best score 1.75
# saved eps_4511
# episode 4511 score0.4 average score -2.9 best score 1.75
# saved eps_4512
# episode 4512 score-1.3 average score -2.9 best score 1.75
# saved eps_4513
# episode 4513 score-2.9 average score -3.0 best score 1.75
# saved eps_4514
# episode 4514 score-2.3 average score -3.0 best score 1.75
# saved eps_4515
# episode 4515 score-2.6 average score -3.0 best score 1.75
# saved eps_4516
# episode 4516 score-5.0 average score -3.0 best score 1.75
# saved eps_4517
# episode 4517 score5.3 average score -2.9 best score 1.75
# saved eps_4518
# episode 4518 score-2.0 average score -3.0 best score 1.75
# saved eps_4519
# episode 4519 score-7.4 average score -3.1 best score 1.75
# saved eps_4520
# episode 4520 score4.8 average score -3.0 best score 1.75
# saved eps_4521
# episode 4521 score-5.6 average score -3.0 best score 1.75
# saved eps_4522
# episode 4522 score-5.8 average score -3.0 best score 1.75
# saved eps_4523
# episode 4523 score-11.8 average score -3.1 best score 1.75
# saved eps_4524
# episode 4524 score-1.8 average score -3.0 best score 1.75
# saved eps_4525
# episode 4525 score4.2 average score -3.0 best score 1.75
# saved eps_4526
# episode 4526 score-3.2 average score -3.0 best score 1.75
# saved eps_4527
# episode 4527 score-3.7 average score -3.0 best score 1.75
# saved eps_4528
# episode 4528 score-20.1 average score -3.1 best score 1.75
# saved eps_4529
# episode 4529 score-7.1 average score -3.2 best score 1.75
# saved eps_4530
# episode 4530 score-2.1 average score -3.1 best score 1.75
# saved eps_4531
# episode 4531 score-5.7 average score -3.2 best score 1.75
# saved eps_4532
# episode 4532 score-8.4 average score -3.2 best score 1.75
# saved eps_4533
# episode 4533 score-4.7 average score -3.3 best score 1.75
# saved eps_4534
# episode 4534 score-3.7 average score -3.3 best score 1.75
# saved eps_4535
# episode 4535 score-1.1 average score -3.3 best score 1.75
# saved eps_4536
# episode 4536 score-3.6 average score -3.3 best score 1.75
# saved eps_4537
# episode 4537 score-0.1 average score -3.2 best score 1.75
# saved eps_4538
# episode 4538 score-6.2 average score -3.2 best score 1.75
# saved eps_4539
# episode 4539 score3.3 average score -3.1 best score 1.75
# saved eps_4540
# episode 4540 score-2.7 average score -3.1 best score 1.75
# saved eps_4541
# episode 4541 score2.6 average score -3.0 best score 1.75
# saved eps_4542
# episode 4542 score-8.7 average score -3.1 best score 1.75
# saved eps_4543
# episode 4543 score-4.5 average score -3.1 best score 1.75
# saved eps_4544
# episode 4544 score-4.2 average score -3.1 best score 1.75
# saved eps_4545
# episode 4545 score-6.7 average score -3.2 best score 1.75
# saved eps_4546
# episode 4546 score-5.3 average score -3.1 best score 1.75
# saved eps_4547
# episode 4547 score-0.7 average score -3.1 best score 1.75
# saved eps_4548
# episode 4548 score-5.5 average score -3.2 best score 1.75
# saved eps_4549
# episode 4549 score-4.6 average score -3.2 best score 1.75
# saved eps_4550
# episode 4550 score-1.7 average score -3.2 best score 1.75
# saved eps_4551
# episode 4551 score-0.7 average score -3.1 best score 1.75
# saved eps_4552
# episode 4552 score-1.5 average score -3.1 best score 1.75
# saved eps_4553
# episode 4553 score-2.3 average score -3.2 best score 1.75
# saved eps_4554
# episode 4554 score-5.6 average score -3.2 best score 1.75
# saved eps_4555
# episode 4555 score-3.5 average score -3.3 best score 1.75
# saved eps_4556
# episode 4556 score-1.6 average score -3.3 best score 1.75
# saved eps_4557
# episode 4557 score-13.2 average score -3.3 best score 1.75
# saved eps_4558
# episode 4558 score-3.8 average score -3.3 best score 1.75
# saved eps_4559
# episode 4559 score-1.4 average score -3.3 best score 1.75
# saved eps_4560
# episode 4560 score-6.0 average score -3.3 best score 1.75
# saved eps_4561
# episode 4561 score-1.9 average score -3.3 best score 1.75
# saved eps_4562
# episode 4562 score-3.2 average score -3.3 best score 1.75
# saved eps_4563
# episode 4563 score-9.4 average score -3.4 best score 1.75
# saved eps_4564
# episode 4564 score-5.4 average score -3.5 best score 1.75
# saved eps_4565
# episode 4565 score1.4 average score -3.4 best score 1.75
# saved eps_4566
# episode 4566 score-3.3 average score -3.4 best score 1.75
# saved eps_4567
# episode 4567 score-3.6 average score -3.4 best score 1.75
# saved eps_4568
# episode 4568 score-2.1 average score -3.4 best score 1.75
# saved eps_4569
# episode 4569 score-0.3 average score -3.4 best score 1.75
# saved eps_4570
# episode 4570 score2.4 average score -3.3 best score 1.75
# saved eps_4571
# episode 4571 score-1.8 average score -3.4 best score 1.75
# saved eps_4572
# episode 4572 score-10.9 average score -3.5 best score 1.75
# saved eps_4573
# episode 4573 score-1.8 average score -3.4 best score 1.75
# saved eps_4574
# episode 4574 score-2.1 average score -3.4 best score 1.75
# saved eps_4575
# episode 4575 score-4.6 average score -3.4 best score 1.75
# saved eps_4576
# episode 4576 score-5.8 average score -3.5 best score 1.75
# saved eps_4577
# episode 4577 score-5.5 average score -3.5 best score 1.75
# saved eps_4578
# episode 4578 score-1.8 average score -3.4 best score 1.75
# saved eps_4579
# episode 4579 score-7.1 average score -3.3 best score 1.75
# saved eps_4580
# episode 4580 score-1.7 average score -3.3 best score 1.75
# saved eps_4581
# episode 4581 score-3.1 average score -3.3 best score 1.75
# saved eps_4582
# episode 4582 score-1.1 average score -3.3 best score 1.75
# saved eps_4583
# episode 4583 score1.7 average score -3.3 best score 1.75
# saved eps_4584
# episode 4584 score-3.6 average score -3.3 best score 1.75
# saved eps_4585
# episode 4585 score-0.6 average score -3.3 best score 1.75
# saved eps_4586
# episode 4586 score-3.1 average score -3.4 best score 1.75
# saved eps_4587
# episode 4587 score-1.4 average score -3.3 best score 1.75
# saved eps_4588
# episode 4588 score-3.4 average score -3.3 best score 1.75
# saved eps_4589
# episode 4589 score-5.1 average score -3.3 best score 1.75
# saved eps_4590
# episode 4590 score-2.3 average score -3.3 best score 1.75
# saved eps_4591
# episode 4591 score-4.6 average score -3.3 best score 1.75
# saved eps_4592
# episode 4592 score1.1 average score -3.2 best score 1.75
# saved eps_4593
# episode 4593 score-1.1 average score -3.2 best score 1.75
# saved eps_4594
# episode 4594 score1.2 average score -3.1 best score 1.75
# saved eps_4595
# episode 4595 score-6.3 average score -3.1 best score 1.75
# saved eps_4596
# episode 4596 score-0.7 average score -3.0 best score 1.75
# saved eps_4597
# episode 4597 score-3.7 average score -3.0 best score 1.75
# saved eps_4598
# episode 4598 score-11.8 average score -3.2 best score 1.75
# saved eps_4599
# episode 4599 score-0.5 average score -3.1 best score 1.75
# saved eps_4600
# episode 4600 score-17.7 average score -3.3 best score 1.75
# saved eps_4601
# episode 4601 score-6.6 average score -3.3 best score 1.75
# saved eps_4602
# episode 4602 score-2.5 average score -3.3 best score 1.75
# saved eps_4603
# episode 4603 score4.5 average score -3.2 best score 1.75
# saved eps_4604
# episode 4604 score3.2 average score -3.2 best score 1.75
# saved eps_4605
# episode 4605 score-6.3 average score -3.3 best score 1.75
# saved eps_4606
# episode 4606 score2.1 average score -3.3 best score 1.75
# saved eps_4607
# episode 4607 score-2.5 average score -3.3 best score 1.75
# saved eps_4608
# episode 4608 score-1.3 average score -3.3 best score 1.75
# saved eps_4609
# episode 4609 score-3.6 average score -3.3 best score 1.75
# saved eps_4610
# episode 4610 score-0.9 average score -3.3 best score 1.75
# saved eps_4611
# episode 4611 score-4.0 average score -3.3 best score 1.75
# saved eps_4612
# episode 4612 score-1.8 average score -3.4 best score 1.75
# saved eps_4613
# episode 4613 score-9.9 average score -3.4 best score 1.75
# saved eps_4614
# episode 4614 score-1.9 average score -3.4 best score 1.75
# saved eps_4615
# episode 4615 score-3.1 average score -3.4 best score 1.75
# saved eps_4616
# episode 4616 score-1.0 average score -3.4 best score 1.75
# saved eps_4617
# episode 4617 score-0.7 average score -3.4 best score 1.75
# saved eps_4618
# episode 4618 score-3.7 average score -3.5 best score 1.75
# saved eps_4619
# episode 4619 score-4.2 average score -3.4 best score 1.75
# saved eps_4620
# episode 4620 score-0.9 average score -3.5 best score 1.75
# saved eps_4621
# episode 4621 score-1.4 average score -3.4 best score 1.75
# saved eps_4622
# episode 4622 score-5.2 average score -3.4 best score 1.75
# saved eps_4623
# episode 4623 score-1.3 average score -3.3 best score 1.75
# saved eps_4624
# episode 4624 score-2.4 average score -3.3 best score 1.75
# saved eps_4625
# episode 4625 score-5.9 average score -3.4 best score 1.75
# saved eps_4626
# episode 4626 score-4.2 average score -3.4 best score 1.75
# saved eps_4627
# episode 4627 score0.7 average score -3.4 best score 1.75
# saved eps_4628
# episode 4628 score-2.5 average score -3.2 best score 1.75
# saved eps_4629
# episode 4629 score-4.0 average score -3.2 best score 1.75
# saved eps_4630
# episode 4630 score-4.9 average score -3.2 best score 1.75
# saved eps_4631
# episode 4631 score-3.5 average score -3.2 best score 1.75
# saved eps_4632
# episode 4632 score-5.2 average score -3.2 best score 1.75
# saved eps_4633
# episode 4633 score-1.3 average score -3.1 best score 1.75
# saved eps_4634
# episode 4634 score-6.0 average score -3.2 best score 1.75
# saved eps_4635
# episode 4635 score-8.3 average score -3.2 best score 1.75
# saved eps_4636
# episode 4636 score-4.0 average score -3.2 best score 1.75
# saved eps_4637
# episode 4637 score-0.4 average score -3.2 best score 1.75
# saved eps_4638
# episode 4638 score-1.9 average score -3.2 best score 1.75
# saved eps_4639
# episode 4639 score-6.4 average score -3.3 best score 1.75
# saved eps_4640
# episode 4640 score-3.5 average score -3.3 best score 1.75
# saved eps_4641
# episode 4641 score0.9 average score -3.3 best score 1.75
# saved eps_4642
# episode 4642 score-7.2 average score -3.3 best score 1.75
# saved eps_4643
# episode 4643 score-1.9 average score -3.3 best score 1.75
# saved eps_4644
# episode 4644 score-5.5 average score -3.3 best score 1.75
# saved eps_4645
# episode 4645 score-4.2 average score -3.3 best score 1.75
# saved eps_4646
# episode 4646 score-0.2 average score -3.2 best score 1.75
# saved eps_4647
# episode 4647 score-0.4 average score -3.2 best score 1.75
# saved eps_4648
# episode 4648 score-3.5 average score -3.2 best score 1.75
# saved eps_4649
# episode 4649 score-0.0 average score -3.1 best score 1.75
# saved eps_4650
# episode 4650 score-6.5 average score -3.2 best score 1.75
# saved eps_4651
# episode 4651 score3.1 average score -3.2 best score 1.75
# saved eps_4652
# episode 4652 score-9.4 average score -3.2 best score 1.75
# saved eps_4653
# episode 4653 score-1.2 average score -3.2 best score 1.75
# saved eps_4654
# episode 4654 score-5.9 average score -3.2 best score 1.75
# saved eps_4655
# episode 4655 score-1.0 average score -3.2 best score 1.75
# saved eps_4656
# episode 4656 score-4.9 average score -3.2 best score 1.75
# saved eps_4657
# episode 4657 score-6.9 average score -3.2 best score 1.75
# saved eps_4658
# episode 4658 score-5.0 average score -3.2 best score 1.75
# saved eps_4659
# episode 4659 score-3.9 average score -3.2 best score 1.75
# saved eps_4660
# episode 4660 score-1.6 average score -3.2 best score 1.75
# saved eps_4661
# episode 4661 score-3.7 average score -3.2 best score 1.75
# saved eps_4662
# episode 4662 score0.3 average score -3.1 best score 1.75
# saved eps_4663
# episode 4663 score-7.3 average score -3.1 best score 1.75
# saved eps_4664
# episode 4664 score2.3 average score -3.0 best score 1.75
# saved eps_4665
# episode 4665 score1.5 average score -3.0 best score 1.75
# saved eps_4666
# episode 4666 score-0.9 average score -3.0 best score 1.75
# saved eps_4667
# episode 4667 score-3.2 average score -3.0 best score 1.75
# saved eps_4668
# episode 4668 score-6.5 average score -3.1 best score 1.75
# saved eps_4669
# episode 4669 score-2.1 average score -3.1 best score 1.75
# saved eps_4670
# episode 4670 score-2.6 average score -3.1 best score 1.75
# saved eps_4671
# episode 4671 score-5.5 average score -3.2 best score 1.75
# saved eps_4672
# episode 4672 score1.6 average score -3.0 best score 1.75
# saved eps_4673
# episode 4673 score2.0 average score -3.0 best score 1.75
# saved eps_4674
# episode 4674 score-3.5 average score -3.0 best score 1.75
# saved eps_4675
# episode 4675 score0.3 average score -3.0 best score 1.75
# saved eps_4676
# episode 4676 score1.1 average score -2.9 best score 1.75
# saved eps_4677
# episode 4677 score-3.0 average score -2.9 best score 1.75
# saved eps_4678
# episode 4678 score-4.4 average score -2.9 best score 1.75
# saved eps_4679
# episode 4679 score-1.2 average score -2.8 best score 1.75
# saved eps_4680
# episode 4680 score5.5 average score -2.8 best score 1.75
# saved eps_4681
# episode 4681 score-1.9 average score -2.8 best score 1.75
# saved eps_4682
# episode 4682 score-0.0 average score -2.8 best score 1.75
# saved eps_4683
# episode 4683 score-5.0 average score -2.8 best score 1.75
# saved eps_4684
# episode 4684 score-3.1 average score -2.8 best score 1.75
# saved eps_4685
# episode 4685 score-3.1 average score -2.8 best score 1.75
# saved eps_4686
# episode 4686 score-5.2 average score -2.9 best score 1.75
# saved eps_4687
# episode 4687 score-4.8 average score -2.9 best score 1.75
# saved eps_4688
# episode 4688 score-15.2 average score -3.0 best score 1.75
# saved eps_4689
# episode 4689 score-1.6 average score -3.0 best score 1.75
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-689e0d2021fb> in <module>()
#      36             if evaluate:
#      37                 env.render()
# ---> 38             actions = maddpg_agents.choose_action(obs)
#      39             obs_, reward, done, info = env.step(actions)
#      40
#
# /content/gdrive/My Drive/Reinforcement Learning/actor_critic/MADDPG/maddpg.py in choose_action(self, raw_obs)
#      30         actions = []
#      31         for agent_idx, agent in enumerate(self.agents):
# ---> 32             action = agent.choose_action(raw_obs[agent_idx])
#      33             actions.append(action)
#      34         return actions
#
# /content/gdrive/My Drive/Reinforcement Learning/actor_critic/MADDPG/agent.py in choose_action(self, observation)
#      26
#      27     def choose_action(self, observation):
# ---> 28         state = T.tensor([observation], dtype=T.float).to(self.actor.device)
#      29         actions = self.actor.forward(state)
#      30         noise = T.rand(self.n_actions).to(self.actor.device)
#
# KeyboardInterrupt:
